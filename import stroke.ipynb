# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
df
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.head(2)
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
#
#    stroke
# 0       1
# 1       1

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
df.info
# Out:
# <bound method DataFrame.info of          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
df.shape
# Out:
# (5110, 12)

# %%
plt.figure(figsize=(20,6))
sns.barplot(x="age" , y="stroke" , data= df)
plt.title("Bar Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="gender" , y="stroke" , data= df)
plt.title("Bar Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="smoking_status" , y="stroke" , data= df)
plt.title("Bar Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="bmi" , y="stroke" , data= df)
plt.title("Bar Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="work_type" , y="stroke" , data=df ,marker="h")
plt.title("Line Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="age" , y="stroke" , data=df ,marker="*")
plt.title("Line Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="Residence_type" , y="stroke" , data=df ,marker="s")
plt.title("Line Chart")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Residence_type" , y="stroke" , data=df , s=100)
plt.title("Scatter Plot")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="gender" , y="stroke" , data=df , s=100)
plt.title("Scatter Plot")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="gender" , y="stroke" , data=df )
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="work_type" , y="stroke" , data=df)
plt.title("Box Plot")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["stroke"], bins=5 , kde=True)
plt.title("Histogram")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["stroke"], bins=5 , kde=False)
plt.title("Histogram")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# age                         0.238171  0.333398  0.245257
# hypertension                0.174474  0.167811  0.127904
# heart_disease               0.161857  0.041357  0.134914
# avg_glucose_level           1.000000  0.175502  0.131945
# bmi                         0.175502  1.000000  0.042374
# ...

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True) ,annot=True, annot_kws=dict(size=10), vmin=-1,vmax=1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
filtration_corr=df.corr(numeric_only=True)[(df.corr(numeric_only=True)>=0.5) | (df.corr(numeric_only=True)<=0.5)]
print(filtration_corr)
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.003084  0.333398      0.167811       0.041357
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.003084  0.006388
# age                         0.238171  0.333398  0.245257
# hypertension                0.174474  0.167811  0.127904
# heart_disease               0.161857  0.041357  0.134914
# avg_glucose_level           1.000000  0.175502  0.131945
# bmi                         0.175502  1.000000  0.042374
# ...

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
df["stroke"].describe()
# Out:
# count    5110.000000
# mean        0.048728
# std         0.215320
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: stroke, dtype: float64

# %%
p1=sns.boxplot(x=df["stroke"])

# %%
outliers = df[(df["stroke"]>1 ) | (df["stroke"]<0)]

# %%
outliers["stroke"]
# Out:
# Series([], Name: stroke, dtype: int64)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import plot_tree
